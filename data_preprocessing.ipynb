# %%
import numpy as np
import pandas as pd
import string
from datasets import load_dataset
import nltk

# %%
def preprocess_dataset(dataset):
    # Convert from pyarrow to pandas df
    df = dataset.to_pandas()
    
    # Map letter answers to options list indices
    df['answer'] = df['answer'].map({'A':0, 'B':1, 'C':2, 'D':3})
    options_series = df['options']

    def is_valid_options(options_list):
        # Strip option, remove punctuation, return True if not all options are just numbers.
        is_valid = [not sent.strip().translate(str.maketrans('', '', string.punctuation)).isnumeric() for sent in options_list]
        return any(is_valid)

    # Map is_valid_options to every question
    is_valid_series = options_series.map(is_valid_options)
    num_dropped = is_valid_series.value_counts()[False]
    print(f'Dropped {num_dropped} rows with only numeric answers')
    return df[is_valid_series]

# %%
race = load_dataset('race', 'all')
val_df = preprocess_dataset(race['validation'])
val_df
# Out:
# Reusing dataset race (/Users/rohith/.cache/huggingface/datasets/race/all/0.1.0/5839ff74a429622f5f20cca69c5fcf0e87ac6d5fd2777c42b948000684829f7b)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dropped 67 rows with only numeric answers
#           example_id                                            article  \
# 0       high5060.txt  I am a psychologist. I first met Timothy, a qu...
# 1       high5060.txt  I am a psychologist. I first met Timothy, a qu...
# 2       high5060.txt  I am a psychologist. I first met Timothy, a qu...
# 3      high14410.txt  From self-driving cars to carebots (care+robot...
# 4      high14410.txt  From self-driving cars to carebots (care+robot...
# ...              ...                                                ...
# 4882  middle5525.txt  John and Jack met at the old bench every after...
# 4883  middle5525.txt  John and Jack met at the old bench every after...
# 4884  middle7740.txt  Everyone has got two personalities --- the one...
# 4885  middle7740.txt  Everyone has got two personalities --- the one...
# 4886  middle7740.txt  Everyone has got two personalities --- the one...
#
#       answer                                           question  \
# 0          2  What did the writer think of Timothy after lea...
# 1          0  Which of the following statements best describ...
# 2          2  According to the passage, how long should a th...
# 3          0                    According to the report,   _  .
# 4          1  We can infer from the text that in the future ...
# ...      ...                                                ...
# 4882       1   John sat on the beach and probably waited for  _
# 4883       2            What is the best title for the passage?
# 4884       0               You may find this passage in   _   .
# 4885       1  Tina hardly tells her secrets to her friends ....
# 4886       2                    What does the passage tell us ?
#
#                                                 options
# 0     [Timothy was very hardworking., Timothy was be...
# 1     [Children should be allowed enough time to pla...
# 2     [About ten minutes., No more than twenty minut...
# 3     [people won't necessarily lose jobs, big compa...
# 4     [people will face many difficulties, people wi...
# ...                                                 ...
# 4882              [his mother, Jack, Steven, his uncle]
# 4883  [A birthday present, A football match, A home-...
# 4884  [a science magazine, A shopping guide book, a ...
# 4885  [curled up, on her stomach, on her back, on he...
# 4886  [Sleeping on you side is the best way of sleep...
#
# [4820 rows x 5 columns]
